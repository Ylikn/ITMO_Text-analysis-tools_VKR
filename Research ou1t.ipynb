# %%
import pandas as pd

# %%
df= pd.read_json('ou1t')
df.columns = ['id', 'file_path', 'text', 'aim', 'count_simbols', 'degree', 'year', 'department', 'diploma_name', 'diploma_name_']
print(len(df))
df.head()
# Out:
# 405
#    id                                          file_path  \
# 0   0  E:\OneDrive\НИКОР 2019 - 2020\2021\ВКР\pdf\бак...
# 1   1  E:\OneDrive\НИКОР 2019 - 2020\2021\ВКР\pdf\бак...
# 2   2  E:\OneDrive\НИКОР 2019 - 2020\2021\ВКР\pdf\бак...
# 3   3  E:\OneDrive\НИКОР 2019 - 2020\2021\ВКР\pdf\бак...
# 4   4  E:\OneDrive\НИКОР 2019 - 2020\2021\ВКР\pdf\бак...
#
#                                                 text    aim  count_simbols  \
# 0  Введение Долгое  время  для  наблюдения  за  л...  False           3330
# 1  ВВЕДЕНИЕ В данной работе затрагивается проблем...   True          69640
# 2  Введение    Система  обнаружения  вторжений  (...  False           2199
# 3  Введение  Современные  компьютерные  технологи...   True          99219
# 4                                                     False              0
#
#       degree  year department  \
# 0  бакалавры  2020       ФБИТ
# 1  бакалавры  2020       ФБИТ
# 2  бакалавры  2020       ФБИТ
# 3  бакалавры  2020       ФБИТ
# ...

# %%
set(df['degree'])
# Out:
# {'бакалавры'}

# %%
df['text'].values[1]
# Out:
# 'ВВЕДЕНИЕ В данной работе затрагивается проблема обеспечения информационной безопасности  на  личном  и/или  социальном  уровне  от  угроз  социальной инженерии. Актуальность проблемы обусловлена тем, что в настоящее время большое  внимание  уделяется  программно-аппаратным  и  техническим средствам  защиты  информации,  но  игнорируются  особенности  психологии человека,  как  отдельного  звена  в  цепи  обеспечения  информационной безопасности автоматизированной системы. Информация – самостоятельный актив,  который  вне  зависимости  от  форм  собственности,  а  также  вида деятельности  организаций  является  основой  для  принятия  важнейших управленческих  решений.  Данное  явление  становится  причиной  роста интереса  злоумышленников  к  конфиденциальной  информации  и  всплеску разнообразных атак на нее.  Однако,  проблема гораздо глубже: учитывая  то, что  в  основе  атак  средствами  социальной  инженерии  лежат  знания  в  сфере психологии  человека,  без  определенной  по
# ...

# %%
print(df['file_path'].values[0])
print(df['diploma_name'].values[0])
# Out:
# E:\OneDrive\НИКОР 2019 - 2020\2021\ВКР\pdf\бакалавры\2020\ФБИТ\Анализ методов обеспечения безопасной передачи данных при взаимодействии с устройствами Интернета вещей.pdf
# Анализ методов обеспечения безопасной передачи данных при взаимодействии с устройствами Интернета вещей.pdf

# %%
df['diploma_name_'].values
# Out:
# array([None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None,
#        'Проект завода по производству сметано-творожной продукции для города с населением 450 тыс. человек, в Северо-Западном регионе России.pdf',
#        'Проект цеха по производству глазури мощностью 2 тонны в смену.pdf',
# ...

# %%
d = df[df['diploma_name_'] == 'Проект завода по производству сметано-творожной продукции для города с населением 450 тыс. человек, в Северо-Западном регионе России.pdf']
print(d['file_path'].values)
print(d['diploma_name_'].values)
# Out:
# ['E:\\OneDrive\\НИКОР 2019 - 2020\\2021\\ВКР\\pdf\\бакалавры\\2020\\ФБТ\\ПБ\\Проект завода по производству сметано-творожной продукции для города с населением 450 тыс. человек, в Северо-Западном регионе России.pdf']
# ['Проект завода по производству сметано-творожной продукции для города с населением 450 тыс. человек, в Северо-Западном регионе России.pdf']
